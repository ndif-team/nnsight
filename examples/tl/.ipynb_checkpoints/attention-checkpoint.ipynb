# %%
import circuitsvis as cv
# Testing that the library works
cv.examples.hello("Neel")
# Out:
# Using renderer: notebook_connected
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# <div id="circuits-vis-1e720799-3af2" style="margin: 15px 0;"/>
#     <script crossorigin type="module">
#     import { render, AttentionPatterns } from "https://unpkg.com/circuitsvis@1.41.0/dist/cdn/esm.js";
#     render(
#       "circuits-vis-1e720799-3af2",
#       AttentionPatterns,
# ...

# %%
vis
# Out:
# <div id="circuits-vis-6fb6130d-30d4" style="margin: 15px 0;"/>
#     <script crossorigin type="module">
#     import { render, AttentionPatterns } from "https://unpkg.com/circuitsvis@1.41.0/dist/cdn/esm.js";
#     render(
#       "circuits-vis-6fb6130d-30d4",
#       AttentionPatterns,
# ...
